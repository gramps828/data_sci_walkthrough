# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('netflix_titles.csv')
print(df.dtypes)
df2 = df
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df.shape
# Out:
# (7787, 12)

# %%
df.shape
# Out:
# (7787, 12)

# %%
df.isnull().sum().sort_values(ascending=True)
# Out:
# show_id            0
# type               0
# title              0
# release_year       0
# duration           0
# listed_in          0
# description        0
# rating             7
# date_added        10
# country          507
# cast             718
# director        2389
# dtype: int64

# %%
for column in df.columns:
    df_mean = df[column].isnull().mean()
    print(f'{column}: {round(percentage*100, 2)}%')
# Out:
# show_id: 0.0%
# type: 0.0%
# title: 0.0%
# director: 30.68%
# cast: 9.22%
# country: 6.51%
# date_added: 0.13%
# release_year: 0.0%
# rating: 0.09%
# duration: 0.0%
# listed_in: 0.0%
# description: 0.0%

# %%
df.drop("director", axis=1)
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
#no_director = df[df["director"].isnull()].index
#df.drop(no_director, axis = 0)

#df[~df["director"].isnull()]

#df.dropna(subset=['director'], inplace=True)
# Out:
# show_id           0
# type              0
# title             0
# director          0
# cast            419
# country         205
# date_added        0
# release_year      0
# rating            4
# duration          0
# listed_in         0
# description       0
# dtype: int64

# %%
mode = ''.join(df['rating'].mode())
df['rating'].fillna(mode)
# Out:
# 1       TV-MA
# 2           R
# 3       PG-13
# 4       PG-13
# 5       TV-MA
#         ...
# 7780    TV-MA
# 7781       PG
# 7782    TV-MA
# 7783    TV-14
# 7786    TV-MA
# Name: rating, Length: 5398, dtype: object

# %%
df_movie = df[df['type']=='Movie']
df_movie = df_movie.assign(minute = df_movie['duration'].str.extract(r'(\d+)', expand=False).astype(int))

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)
plt.hist(df_movie['minute'])
fig.tight_layout()

# %%
fig, ax=plt.subplots(nrows=1, ncols=1)
ax = sns.boxplot(x=df_movie['minute'])
fig.tight_layout()

# %%
df_movie.describe()
# Out:
#        release_year       minute
# count   5214.000000  5214.000000
# mean    2012.828539   100.285194
# std        9.729851    27.689154
# min     1942.000000     3.000000
# 25%     2012.000000    87.000000
# 50%     2016.000000    98.000000
# 75%     2018.000000   115.000000
# max     2021.000000   253.000000

# %%
'''import plotly.graph_objects as go
from plotly.offline import iplot, init_notebook_mode

fig.add_box(x=df_movie['minute'], text=df_movie['minute'])
iplot(fig)'''
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-53-04f6937d5f37> in <module>
# ----> 1 import plotly.graph_objects as go
#       2 from plotly.offline import iplot, init_notebook_mode
#       3
#       4 fig.add_box(x=df_movie['minute'], text=df_movie['minute'])
#       5 iplot(fig)
#
# ModuleNotFoundError: No module named 'plotly'

# %%
fig=df['rating'].value_counts().plot.bar().get_figure()
fig.tight_layout()

# %%
df_movie[(df_movie['minute']<43) | (df_movie['minute']>158)]
df_movie = df_movie[(df_movie['minute']>43) & (df_movie['minute']<158)]

# %%
df2.rename(columns={'title': 'butt', 'release_year': 'ass_to_mouth'}, inplace=True)

# %%
df2.dtypes
# Out:
# show_id         object
# type            object
# butt            object
# director        object
# cast            object
# country         object
# date_added      object
# ass_to_mouth     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df2 = df2.astype({'ass_to_mouth': float})

# %%
df2.dtypes
# Out:
# show_id          object
# type             object
# butt             object
# director         object
# cast             object
# country          object
# date_added       object
# ass_to_mouth    float64
# rating           object
# duration         object
# listed_in        object
# description      object
# dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-63-57bf312e28bf> in <module>
# ----> 1 from fuzzywuzzy import process, fuzz
#
# ModuleNotFoundError: No module named 'fuzzywuzzy'
